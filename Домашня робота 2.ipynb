# %% [markdown]
# # Домашня робота №2

# %% [markdown]
# ## 1 Пароль
# Напишіть програму (функцію) для генерування випадкового пароля з такими обмеженнями:
# - пароль складається з рівно $10$ символів
# - пароль містить хоча б одну маленьку латинську літеру [a-z]
# - пароль містить хоча б одну велику латинську літеру [A-Z]
# - пароль містить хоча б одну цифру [0-9]
# - пароль містить хоча б один спеціальний символ [~!@#$%^&*()-_+=\/{}[].,?<>:;]

# %%
import numpy as np

# %%
import string

S = [string.ascii_lowercase, string.ascii_uppercase, string.digits, '~!@#$%^&*()-_+=/{}[].,?<>:;']


while True:
    password = np.random.choice(list(''.join(S)), 10)
    if not all([any([c in s for c in password]) for s in S]):
        break

print(''.join(password))
# Out:
# y%lUF%Pjx~

# %% [markdown]
# ## 2 Герби в ряд
# Реалізуйте функцію для обчислення емпіричної та теоретичної імовірностей випадіння $k$ гербів (HEADS) підряд у серії з $n$ підкидань чесної монетки. Підрахуйте відповідні ймовірності для таких параметрів:
# - $k = 2, n = 10, 50, 100, 500, 1000, 5000, 10000$
# - $k = 3, n = 10, 50, 100, 500, 1000, 5000, 10000$
#
# **Зауваження.** Нехай $k = 2, n = 10$ та маємо таку послідовність результатів підкидання монети: $\{ H, T, H, H, H, H, T, T, H, T \}$. Тоді матимемо $3$ випадки випадіння двох гербів підряд та емпіричну ймовірність такої події $1/3$.

# %%
N = [10, 50, 100, 500, 1000, 5000, 10000]
K = [2, 3]
for k in K:
    for n in N:
        ht = [np.random.randint(2) for i in range(n)]
        cnt = 0
        for i in range(n-k+1):
            if ht[i:i+k].count(0) == k:
                cnt += 1
        print("N: {:<5} K: {:1} Емпірична імовірність: {:1.4f} Теретична імовірніть: {:1.3f}".format(n, k, cnt/(n-1), 1/2**k))
# Out:
# N: 10    K: 2 Емпірична імовірність: 0.2222 Теретична імовірніть: 0.250
# N: 50    K: 2 Емпірична імовірність: 0.2041 Теретична імовірніть: 0.250
# N: 100   K: 2 Емпірична імовірність: 0.2323 Теретична імовірніть: 0.250
# N: 500   K: 2 Емпірична імовірність: 0.2365 Теретична імовірніть: 0.250
# N: 1000  K: 2 Емпірична імовірність: 0.2543 Теретична імовірніть: 0.250
# N: 5000  K: 2 Емпірична імовірність: 0.2613 Теретична імовірніть: 0.250
# N: 10000 K: 2 Емпірична імовірність: 0.2581 Теретична імовірніть: 0.250
# N: 10    K: 3 Емпірична імовірність: 0.0000 Теретична імовірніть: 0.125
# N: 50    K: 3 Емпірична імовірність: 0.1020 Теретична імовірніть: 0.125
# N: 100   K: 3 Емпірична імовірність: 0.0606 Теретична імовірніть: 0.125
# N: 500   K: 3 Емпірична імовірність: 0.1563 Теретична імовірніть: 0.125
# N: 1000  K: 3 Емпірична імовірність: 0.1151 Теретична імовірніть: 0.125
# N: 5000  K: 3 Емпірична імовірність: 0.1310 Теретична імовірніть: 0.125
# ...

# %% [markdown]
# ## 3 Найбільше число
# Реалізуйте функцію підрахунку точної (теоретичної) імовірності того, що максимальне число після $n$ кидків звичайного грального кубика дорівнює $x\_max$, для таких параметрів:
# - $n = 3, x\_max = 6$
# - $n = 2, x\_max = 3$
# - $n = 3, x\_max = 5$
#
# Тобто, якщо $X_i, i = 1, \ldots, n$, - число на $i$-му кидку кубика, а $X = \max\limits_{1 \leq i \leq n} X_i$, то потрібно знайти ймовірність $\textbf{P} \left( X = x\_max \right)$.
#
# Підрахуйте також емпіричні ймовірності відповідних подій у випадку $10000$ симуляцій.
#
# **Зауваження.** Якщо введені параметри не мають сенсу, то повертати $0$.
# Тобто, якщо вводиться $x\_max < 1$ або $x\_max > 6$.

# %%
A = [ (3, 6), (2, 3), (3, 5)]

for (n, k) in A:
    prob_less_eq = (k/6)**n
    prob_less = ((k-1)/6)**n
    cnt = 0
    for i in range(10000):
        sc = list(np.random.randint(1, 7, n))
        if max(sc)==k:
            cnt += 1
                  
    print("N: {} K: {} Емпірична імовірність: {:1.5f} Теоретична імовірність: {:1.5f}".format(n, k, cnt/10000, prob_less_eq - prob_less))
# Out:
# N: 3 K: 6 Емпірична імовірність: 0.43010 Теоретична імовірність: 0.42130
# N: 2 K: 3 Емпірична імовірність: 0.14540 Теоретична імовірність: 0.13889
# N: 3 K: 5 Емпірична імовірність: 0.27610 Теоретична імовірність: 0.28241

# %% [markdown]
# ## 4 Сума чисел
# Реалізуйте функцію підрахунку точної (теоретичної) імовірності того, що сума чисел після $n$ кидків звичайного грального кубика дорівнює $s$, для таких параметрів:
# - $n = 3, s = 13$
# - $n = 2, s = 5$
# - $n = 3, s = 7$
#
# Тобто, якщо $X_i, i = 1, \ldots, n$, - число на $i$-му кидку кубика, а $X = \sum\limits_{i = 1}^{n} X_i$, то потрібно знайти ймовірність $\textbf{P} \left( X = s \right)$.
#
# Підрахуйте також емпіричні ймовірності відповідних подій у випадку $10000$ симуляцій.
#
# **Зауваження.** Якщо введені параметри не мають сенсу, то повертати $0$.
# Наприклад, якщо при $n = 3$ вводиться $s < 3$ або $s > 18$.

# %%
from math import factorial
def balls(n, s):
    return factorial(s+n-1)/factorial(s)/factorial(n-1)
def c(n,k):
    return factorial(n)/factorial(k)/factorial(n-k)
def prob(n, s):
    k = 0
    res = 0
    m1 = 1
    while s >= n + 6*k:
        res += m1*c(n, k)*balls(n, s - n - 6*k)
        m1 *= -1
        k += 1
    return res/6**n

def simul(n, k):
    s = 0
    for i in range(n):
        s += np.random.randint(1, 7)
    return s == k

def emp(T, n, k):
    cnt = 0
    for i in range(T):
        cnt += simul(n, k)
    return cnt/T
    
A = [(3, 13), (2, 5), (3, 7)]
for n, k in A:
    
    print("N: {} K: {:<2} Теоритична імовірність: {:1.5f} Емпірична імовірність: {:1.5f}".format(n, k, prob(n, k), emp(10000, n, k)))
# Out:
# N: 3 K: 13 Теоритична імовірність: 0.09722 Емпірична імовірність: 0.09200
# N: 2 K: 5  Теоритична імовірність: 0.11111 Емпірична імовірність: 0.11260
# N: 3 K: 7  Теоритична імовірність: 0.06944 Емпірична імовірність: 0.06760
